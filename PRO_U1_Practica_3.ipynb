# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelRios7/Probabilidad-y-estadistica-Unidad-1/blob/main/PRO_U1_Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Angel Rios
#
# ### **Programa 3: Tablas de frecuencias**

# %%
import random
edades=[]

for i in range(100):

  numero_aleatorio=random.randint(18, 70)

  edades.append(numero_aleatorio)

print(edades)
# Out:
# [40, 23, 38, 32, 44, 35, 44, 22, 63, 31, 57, 68, 30, 30, 46, 35, 66, 48, 50, 55, 18, 69, 21, 23, 28, 18, 56, 36, 57, 56, 27, 22, 57, 27, 46, 64, 27, 70, 68, 50, 41, 47, 68, 70, 61, 38, 32, 29, 22, 18, 31, 37, 27, 41, 39, 36, 47, 59, 48, 22, 57, 46, 70, 30, 55, 41, 41, 29, 37, 38, 44, 21, 65, 26, 44, 53, 24, 52, 42, 58, 41, 46, 62, 27, 28, 52, 67, 35, 40, 42, 37, 34, 45, 35, 41, 42, 19, 42, 64, 55]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    40
# 1    23
# 2    38
# 3    32
# 4    44

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribucion de Frecuenias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuenias:
#     Edad  Frecuencia
# 14    18           3
# 44    19           1
# 23    21           2
# 5     22           4
# 19    23           2
# 37    24           1
# 34    26           1
# 1     27           5
# 20    28           2
# 15    29           2
# 10    30           3
# 18    31           2
# 16    32           2
# 42    34           1
# 7     35           4
# 22    36           2
# 13    37           3
# 11    38           3
# 35    39           1
# 17    40           2
# 0     41           6
# 6     42           4
# 4     44           4
# 43    45           1
# 2     46           4
# 25    47           2
# 28    48           2
# 27    50           2
# 26    52           2
# 38    53           1
# 9     55           3
# 24    56           2
# 3     57           4
# 39    58           1
# 36    59           1
# 30    61           1
# 40    62           1
# 29    63           1
# 21    64           2
# 33    65           1
# 31    66           1
# 41    67           1
# 8     68           3
# 32    69           1
# 12    70           3

# %%
tabla_frecuencias['Frec. Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 14    18           3            0.03
# 44    19           1            0.01
# 23    21           2            0.02
# 5     22           4            0.04
# 19    23           2            0.02
# 37    24           1            0.01
# 34    26           1            0.01
# 1     27           5            0.05
# 20    28           2            0.02
# 15    29           2            0.02
# 10    30           3            0.03
# 18    31           2            0.02
# 16    32           2            0.02
# 42    34           1            0.01
# 7     35           4            0.04
# 22    36           2            0.02
# 13    37           3            0.03
# 11    38           3            0.03
# 35    39           1            0.01
# 17    40           2            0.02
# 0     41           6            0.06
# 6     42           4            0.04
# 4     44           4            0.04
# 43    45           1            0.01
# 2     46           4            0.04
# 25    47           2            0.02
# 28    48           2            0.02
# 27    50           2            0.02
# 26    52           2            0.02
# 38    53           1            0.01
# 9     55           3            0.03
# 24    56           2            0.02
# 3     57           4            0.04
# 39    58           1            0.01
# 36    59           1            0.01
# 30    61           1            0.01
# 40    62           1            0.01
# 29    63           1            0.01
# 21    64           2            0.02
# 33    65           1            0.01
# 31    66           1            0.01
# 41    67           1            0.01
# 8     68           3            0.03
# 32    69           1            0.01
# 12    70           3            0.03

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec Porcentual
# 14    18           3            0.03              3.0
# 44    19           1            0.01              1.0
# 23    21           2            0.02              2.0
# 5     22           4            0.04              4.0
# 19    23           2            0.02              2.0
# 37    24           1            0.01              1.0
# 34    26           1            0.01              1.0
# 1     27           5            0.05              5.0
# 20    28           2            0.02              2.0
# 15    29           2            0.02              2.0
# 10    30           3            0.03              3.0
# 18    31           2            0.02              2.0
# 16    32           2            0.02              2.0
# 42    34           1            0.01              1.0
# 7     35           4            0.04              4.0
# 22    36           2            0.02              2.0
# 13    37           3            0.03              3.0
# 11    38           3            0.03              3.0
# 35    39           1            0.01              1.0
# 17    40           2            0.02              2.0
# 0     41           6            0.06              6.0
# 6     42           4            0.04              4.0
# 4     44           4            0.04              4.0
# 43    45           1            0.01              1.0
# 2     46           4            0.04              4.0
# 25    47           2            0.02              2.0
# 28    48           2            0.02              2.0
# 27    50           2            0.02              2.0
# 26    52           2            0.02              2.0
# 38    53           1            0.01              1.0
# 9     55           3            0.03              3.0
# 24    56           2            0.02              2.0
# 3     57           4            0.04              4.0
# 39    58           1            0.01              1.0
# 36    59           1            0.01              1.0
# 30    61           1            0.01              1.0
# 40    62           1            0.01              1.0
# 29    63           1            0.01              1.0
# 21    64           2            0.02              2.0
# 33    65           1            0.01              1.0
# 31    66           1            0.01              1.0
# 41    67           1            0.01              1.0
# 8     68           3            0.03              3.0
# 32    69           1            0.01              1.0
# 12    70           3            0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec Porcentual  Frec Acumulada
# 14    18           3            0.03              3.0               3
# 44    19           1            0.01              1.0               4
# 23    21           2            0.02              2.0               6
# 5     22           4            0.04              4.0              10
# 19    23           2            0.02              2.0              12
# 37    24           1            0.01              1.0              13
# 34    26           1            0.01              1.0              14
# 1     27           5            0.05              5.0              19
# 20    28           2            0.02              2.0              21
# 15    29           2            0.02              2.0              23
# 10    30           3            0.03              3.0              26
# 18    31           2            0.02              2.0              28
# 16    32           2            0.02              2.0              30
# 42    34           1            0.01              1.0              31
# 7     35           4            0.04              4.0              35
# 22    36           2            0.02              2.0              37
# 13    37           3            0.03              3.0              40
# 11    38           3            0.03              3.0              43
# 35    39           1            0.01              1.0              44
# 17    40           2            0.02              2.0              46
# 0     41           6            0.06              6.0              52
# 6     42           4            0.04              4.0              56
# 4     44           4            0.04              4.0              60
# 43    45           1            0.01              1.0              61
# 2     46           4            0.04              4.0              65
# 25    47           2            0.02              2.0              67
# 28    48           2            0.02              2.0              69
# 27    50           2            0.02              2.0              71
# 26    52           2            0.02              2.0              73
# 38    53           1            0.01              1.0              74
# 9     55           3            0.03              3.0              77
# 24    56           2            0.02              2.0              79
# 3     57           4            0.04              4.0              83
# 39    58           1            0.01              1.0              84
# 36    59           1            0.01              1.0              85
# 30    61           1            0.01              1.0              86
# 40    62           1            0.01              1.0              87
# 29    63           1            0.01              1.0              88
# 21    64           2            0.02              2.0              90
# 33    65           1            0.01              1.0              91
# 31    66           1            0.01              1.0              92
# 41    67           1            0.01              1.0              93
# 8     68           3            0.03              3.0              96
# 32    69           1            0.01              1.0              97
# 12    70           3            0.03              3.0             100

# %%
import math

# %%
print (edades)
# Out:
# [40, 23, 38, 32, 44, 35, 44, 22, 63, 31, 57, 68, 30, 30, 46, 35, 66, 48, 50, 55, 18, 69, 21, 23, 28, 18, 56, 36, 57, 56, 27, 22, 57, 27, 46, 64, 27, 70, 68, 50, 41, 47, 68, 70, 61, 38, 32, 29, 22, 18, 31, 37, 27, 41, 39, 36, 47, 59, 48, 22, 57, 46, 70, 30, 55, 41, 41, 29, 37, 38, 44, 21, 65, 26, 44, 53, 24, 52, 42, 58, 41, 46, 62, 27, 28, 52, 67, 35, 40, 42, 37, 34, 45, 35, 41, 42, 19, 42, 64, 55]

# %%
df=pd.DataFrame(edades, columns=['Edad'])
df
# Out:
#     Edad
# 0     40
# 1     23
# 2     38
# 3     32
# 4     44
# ..   ...
# 95    42
# 96    19
# 97    42
# 98    64
# 99    55
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1+math.log2(n))
print("Valor de n=",n, "\nNumero de intervalos =", k)
# Out:
# Valor de n= 100
# Numero de intervalos = 7

# %%
tabla_frecuencia=pd.cut(df['Edad'],bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    21
# 1  (25.429, 32.857]    17
# 2  (32.857, 40.286]    16
# 3  (17.947, 25.429]    13
# 4    (62.571, 70.0]    13
# 5  (47.714, 55.143]    10
# 6  (55.143, 62.571]    10

# %%
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3  (17.947, 25.429]    13
# 1  (25.429, 32.857]    17
# 2  (32.857, 40.286]    16
# 0  (40.286, 47.714]    21
# 5  (47.714, 55.143]    10
# 6  (55.143, 62.571]    10
# 4    (62.571, 70.0]    13

# %%
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Por']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac']=tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Por Ac']=tabla_frecuencia['Frec Por'].cumsum()
tabla_frecuencia

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Por  Frec Ac  Frec Rel Ac  \
# 3  (17.947, 25.429]    13      0.13      13.0       13         0.13
# 1  (25.429, 32.857]    17      0.17      17.0       30         0.30
# 2  (32.857, 40.286]    16      0.16      16.0       46         0.46
# 0  (40.286, 47.714]    21      0.21      21.0       67         0.67
# 5  (47.714, 55.143]    10      0.10      10.0       77         0.77
# 6  (55.143, 62.571]    10      0.10      10.0       87         0.87
# 4    (62.571, 70.0]    13      0.13      13.0      100         1.00
#
#    Frec Por Ac
# 3         13.0
# 1         30.0
# 2         46.0
# 0         67.0
# 5         77.0
# 6         87.0
# 4        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
