# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelRios7/Probabilidad-y-estadistica-Unidad-1/blob/main/PRO_U1_Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Angel Rios
#
# ### **Programa 4: Diagramas de Cajas y bigotes**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [84.68, 80.73, 60.37, 74.98, 64.49, 91.4, 75.93, 87.23, 57.3, 74.84, 87.02, 82.43, 98.61, 64.52, 74.06, 54.03, 51.01, 86.58, 66.8, 80.93, 69.93, 88.11, 68.41, 97.79, 76.02, 51.84, 56.5, 99.65, 76.1, 70.34, 74.22, 60.48, 51.37, 75.3, 91.86, 54.94, 75.51, 61.78, 83.7, 98.84, 61.41, 78.46, 79.46, 74.95, 92.4, 72.88, 62.95, 99.28, 99.55, 90.0, 75.2, 77.48, 50.12, 81.55, 58.0, 85.77, 50.89, 72.5, 74.7, 87.92, 77.29, 55.05, 57.33, 85.01, 87.54, 53.1, 79.23, 97.18, 81.48, 53.96, 65.33, 58.72, 55.02, 63.41, 60.55, 69.68, 86.5, 82.21, 81.44, 87.72, 68.57, 84.12, 74.54, 83.94, 57.58, 76.36, 55.38, 95.51, 85.09, 99.56, 85.4, 93.56, 71.05, 87.78, 67.79, 97.88, 57.37, 63.81, 64.89, 90.86]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [48.15, 44.82, 78.7, 72.04, 89.79, 49.51, 61.61, 70.37, 71.72, 71.23, 66.19, 80.52, 52.06, 79.59, 89.7, 56.71, 54.78, 80.59, 67.08, 83.17, 42.34, 44.5, 57.89, 77.02, 85.54, 65.11, 54.78, 57.45, 58.32, 41.78, 66.8, 73.29, 42.61, 65.53, 73.58, 44.77, 48.43, 60.74, 68.59, 71.97, 63.42, 54.8, 86.04, 70.72, 52.15, 72.58, 53.11, 57.52, 59.52, 58.78, 44.24, 52.87, 65.58, 85.31, 71.49, 54.3, 80.96, 65.36, 41.75, 69.46, 65.88, 45.56, 63.64, 64.71, 64.56, 69.28, 62.84, 91.8, 75.43, 45.37, 44.19, 74.29, 50.7, 57.27, 71.67, 68.15, 65.33, 88.08, 51.71, 77.13, 89.99, 81.87, 64.23, 47.26, 81.38, 51.39, 86.95, 62.21, 51.22, 55.52, 45.93, 64.88, 48.34, 72.23, 88.89, 75.53, 85.4, 86.28, 67.34, 80.26]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(fabrica1,
                  vert=True) #Alineacion Vertical
ax1.set_title('Produccion fabrica 1')

bplot2=ax2.boxplot(fabrica2,
                   vert=True) #Alineacion Vertical
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [84.68, 80.73, 60.37, 74.98, 64.49, 91.4, 75.93, 87.23, 57.3, 74.84, 87.02, 82.43, 98.61, 64.52, 74.06, 54.03, 51.01, 86.58, 66.8, 80.93, 69.93, 88.11, 68.41, 97.79, 76.02, 51.84, 56.5, 99.65, 76.1, 70.34, 74.22, 60.48, 51.37, 75.3, 91.86, 54.94, 75.51, 61.78, 83.7, 98.84, 61.41, 78.46, 79.46, 74.95, 92.4, 72.88, 62.95, 99.28, 99.55, 90.0, 75.2, 77.48, 50.12, 81.55, 58.0, 85.77, 50.89, 72.5, 74.7, 87.92, 77.29, 55.05, 57.33, 85.01, 87.54, 53.1, 79.23, 97.18, 81.48, 53.96, 65.33, 58.72, 55.02, 63.41, 60.55, 69.68, 86.5, 82.21, 81.44, 87.72, 68.57, 84.12, 74.54, 83.94, 57.58, 76.36, 55.38, 95.51, 85.09, 99.56, 85.4, 93.56, 71.05, 87.78, 67.79, 97.88, 57.37, 63.81, 64.89, 90.86, 150]

# %%
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(fabrica1,
                   vert=True, #vertical box aligment
                   patch_artist=True)#fill with color
ax1.set_title('Produccion fabrica 1')

bplot2=ax2.boxplot(fabrica2,
                   vert=True, #vertical box aligment
                   patch_artist=True)#fill with color
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,5))
bplot1=ax1.boxplot(fabrica1,
                   vert=True, #Alineacion Vertical t
                   patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')
ax1.set_ylim(30,100)#Escala uniforme de 0 a 160

bplot2=ax2.boxplot(fabrica2,
                   vert=True, #Alineacion Vertical
                   patch_artist=True)#Rellenar con color

ax2.set_title('Produccion fabrica 2')
ax2.set_ylim(30,100)#Escala uniforme de 0 a 160
plt.show()
