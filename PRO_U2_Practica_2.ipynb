# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelRios7/Probabilidad-y-estadistica-Unidad-1/blob/main/PRO_U2_Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Angel Rios
#
# ### **Programa 2: Maximo, minimo y dispersión de datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50,100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [97.95, 75.88, 82.36, 79.57, 64.54, 60.83, 50.82, 56.09, 51.06, 53.53, 55.27, 77.77, 88.54, 58.44, 97.64, 84.92, 98.54, 89.18, 88.67, 81.67, 92.53, 52.99, 66.04, 82.18, 97.36, 86.84, 58.89, 71.46, 55.44, 62.7, 79.09, 77.32, 66.02, 78.52, 65.58, 51.4, 99.7, 79.77, 63.48, 98.39, 68.22, 69.99, 71.77, 57.8, 67.36, 76.28, 55.04, 76.63, 62.79, 85.43, 87.09, 70.6, 68.67, 61.13, 59.31, 80.98, 52.65, 82.24, 82.76, 81.59, 99.89, 97.59, 76.73, 99.74, 82.41, 87.01, 67.35, 81.69, 65.6, 68.31, 52.26, 85.8, 93.89, 95.57, 88.05, 80.08, 51.38, 81.0, 52.29, 56.78, 56.6, 58.0, 67.95, 91.52, 90.94, 90.31, 69.95, 78.87, 69.15, 53.77, 62.01, 84.58, 62.58, 65.33, 62.09, 65.9, 61.05, 86.59, 97.48, 98.46]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50,100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [50.16, 89.12, 82.86, 90.85, 69.56, 84.39, 77.19, 89.47, 65.68, 83.25, 98.02, 51.89, 68.03, 69.16, 95.73, 59.98, 72.3, 86.12, 88.85, 75.68, 87.84, 71.24, 77.5, 63.52, 72.73, 93.92, 55.59, 97.98, 75.16, 59.47, 85.31, 51.35, 98.28, 57.97, 52.02, 55.43, 76.58, 71.62, 51.17, 59.56, 68.55, 69.77, 74.06, 77.13, 80.49, 55.14, 52.14, 95.44, 64.33, 87.32, 56.52, 77.87, 94.47, 99.18, 68.38, 71.15, 85.13, 52.66, 91.62, 76.43, 95.5, 99.06, 50.37, 93.1, 64.03, 74.6, 56.46, 79.76, 68.27, 70.86, 68.17, 55.06, 91.97, 71.07, 54.78, 64.86, 85.67, 83.86, 70.14, 52.83, 94.72, 96.29, 54.77, 90.11, 84.3, 84.84, 58.28, 75.65, 78.36, 93.12, 64.66, 99.41, 86.01, 72.81, 91.78, 56.73, 64.92, 65.79, 75.41, 85.28]

# %%
#Maximo, minimo y rango
maximo1= max(fabrica1)
minimo1= min(fabrica1)
rango1= maximo1-minimo1
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
desviacion1= stdev(fabrica1)
print("Estadística descriptiva de la Fabrica 1 \n", "media =", media1, "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1, "\n Minimo =", minimo1, "\n Rango =", rango1)
print("Desviacion Estandar =", desviacion1)
# Out:
# Estadística descriptiva de la Fabrica 1
#  media = 74.3385
#  Mediana = 76.08
#  Moda = 97.95
#  Maximo = 99.89
#  Minimo = 50.82
#  Rango = 49.07
# Desviacion Estandar = 14.740391520299493

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica1, bins = 10, alpha= 0.2, color= 'b', edgecolor="black" )
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='y', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 + desviacion1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion1:.2f}')
plt.axvline(media1 - desviacion1, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()

# %%
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2= maximo2-minimo2
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
desviacion2= stdev(fabrica2)
print("Estadística descriptiva de la Fabrica 2 \n", "media =", media2, "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2, "\n Minimo =", minimo2, "\n Rango =", rango2)
print("Desviacion Estandar =", desviacion2)
# Out:
# Estadística descriptiva de la Fabrica 2
#  media = 74.8397
#  Mediana = 74.88
#  Moda = 50.16
#  Maximo = 99.41
#  Minimo = 50.16
#  Rango = 49.25
# Desviacion Estandar = 14.640337279812465

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion2 = stdev(fabrica2)

plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins = 10, alpha= 0.2, color= 'b', edgecolor="black" )
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='y', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='g', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 + desviacion2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion2:.2f}')
plt.axvline(media2 - desviacion2, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()

# %%
import seaborn as sns

# %%
sns.histplot( x=fabrica1, kde= True, kde_kws={'bw_adjust':0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
